# %%
import graphlab
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = graphlab.SFrame.read_csv("1m.csv",
                                column_type_hints={"UserID": int, 
                                                   "MovieTitle": str, 
                                                   "Ratings": int})

# %%
data = data.select_columns(["UserID", "MovieTitle", "Ratings"])

# %%
data.head()
# Out:
#    UserID                              MovieTitle  Ratings
# 0       1  One Flew Over the Cuckoo's Nest (1975)        5
# 1       1        James and the Giant Peach (1996)        3
# 2       1                     My Fair Lady (1964)        3
# 3       1                  Erin Brockovich (2000)        4
# 4       1                    Bug's Life, A (1998)        5
# 5       1              Princess Bride, The (1987)        3
# 6       1                          Ben-Hur (1959)        5
# 7       1               Christmas Story, A (1983)        5
# 8       1  Snow White and the Seven Dwarfs (1937)        4
# 9       1                Wizard of Oz, The (1939)        4
#
# [10 rows x 3 columns]

# %% [markdown]
# # Making recommendations to new users

# %% [markdown]
# ## Rate movies

# %% [markdown]
# ### Action lover

# %%
action_movies = graphlab.SArray(["GoldenEye (1995)",
                                 "Braveheart (1995)",
                                 "Terminator 2: Judgment Day (1991)",
                                 "Die Hard (1988)",
                                 "Top Gun (1986)",
                                 "Indiana Jones and the Last Crusade (1989)",
                                 "Crow, The (1994)",
                                 "Cop Land (1997)"],
                                str)
action_ratings = graphlab.SArray([5, 4, 5, 5, 3, 4, 4, 5], int)
action_userid = graphlab.SArray([9000] * action_movies.size(), int)

action_lover = graphlab.SFrame()
action_lover.add_column(action_userid, "UserID")
action_lover.add_column(action_movies, "MovieTitle")
action_lover.add_column(action_ratings, "Ratings")

# %% [markdown]
# ### Romance lover

# %%
romance_movies = graphlab.SArray(["Mad Love (1995)",
                                  "Sabrina (1995)",
                                  "While You Were Sleeping (1995)",
                                  "Sleepless in Seattle (1993)",
                                  "Dirty Dancing (1987)",
                                  "When Harry Met Sally... (1989)",
                                  "Jerry Maguire (1996)",
                                  "Pretty Woman (1990)"],
                                 str)
romance_ratings = graphlab.SArray([5, 4, 5, 3, 4, 5, 5, 4], int)
romance_userid = graphlab.SArray([9001] * romance_movies.size(), int)

romance_lover = graphlab.SFrame()
romance_lover.add_column(romance_userid, "UserID")
romance_lover.add_column(romance_movies, "MovieTitle")
romance_lover.add_column(romance_ratings, "Ratings")

# %% [markdown]
# ## Recommend movies
# We need to update the model with the ratings of the action and romance lovers.

# %%
df = data.to_dataframe()
df = df.append(action_lover.to_dataframe())
df = df.append(romance_lover.to_dataframe())
new_data = graphlab.SFrame(data=df)

# %%
new_data.tail(16)
# Out:
#     UserID                                 MovieTitle  Ratings
# 0     9000                           GoldenEye (1995)        5
# 1     9000                          Braveheart (1995)        4
# 2     9000          Terminator 2: Judgment Day (1991)        5
# 3     9000                            Die Hard (1988)        5
# 4     9000                             Top Gun (1986)        3
# 5     9000  Indiana Jones and the Last Crusade (1989)        4
# 6     9000                           Crow, The (1994)        4
# 7     9000                            Cop Land (1997)        5
# 8     9001                            Mad Love (1995)        5
# 9     9001                             Sabrina (1995)        4
# 10    9001             While You Were Sleeping (1995)        5
# 11    9001                Sleepless in Seattle (1993)        3
# 12    9001                       Dirty Dancing (1987)        4
# 13    9001             When Harry Met Sally... (1989)        5
# 14    9001                       Jerry Maguire (1996)        5
# 15    9001                        Pretty Woman (1990)        4
#
# [16 rows x 3 columns]

# %%
optimal_model = graphlab.recommender.matrix_factorization.create(new_data, "UserID", "MovieTitle", "Ratings", D=150, reg=0.1)

# %%
optimal_model.training_stats()
# Out:
# {'data_load_time': 1.011968,
#  'elapsed_time': 101.451048,
#  'global_bias': 3.581577145142343,
#  'niter': 10,
#  'num_obs_train': 1000225,
#  'num_obs_validate': 0,
#  'obj_value': [343270.2847935192,
#   185116.75597975875,
#   144721.65871348808,
#   123731.83830212316,
#   110177.55228627517,
#   100478.39069638452,
#   93091.6684995451,
#   87229.87724957129,
#   82439.47775669844,
#   78435.42344352271],
#  'rmse_progress': [0.5380868386229707,
#   0.3742015821570529,
#   0.3238717427557909,
#   0.2962869880517095,
#   0.2777980151913063,
#   0.2641963455667154,
#   0.2536067358957073,
#   0.24504638361884987,
#   0.23794093649042428,
#   0.2319218323155687],
#  'runtime': 98.440669,
#  'training_rmse': 0.2319218323155687,
#  'training_time': 100.43908}

# %%
optimal_stats = optimal_model.evaluate(new_data)
# Out:
# Overall RMSE:  0.231921832316
#
# Per User RMSE (best)
#    UserID      rmse  count
# 0    3324  0.011674     21
#
# [1 rows x 3 columns]
# Per User RMSE (worst)
#    UserID      rmse  count
# 0    5367  0.412566   1169
#
# [1 rows x 3 columns]
# Per Item RMSE (best)
#                                     MovieTitle  rmse  count
# 0  Five Wives, Three Secretaries and Me (1998)     0      1
#
# [1 rows x 3 columns]
# Per Item RMSE (worst)
#                      MovieTitle      rmse  count
# 0  Good Morning, Vietnam (1987)  0.357935   1082
#
# [1 rows x 3 columns]

# %% [markdown]
# ### Action lover
# The top ten recommendations for the action lover are the following:

# %%
action_recommendations = optimal_model.recommend(new_data, users=[9000], k=10)
action_recommendations.head(10)
# Out:
#    UserID                                         MovieTitle     score  rank
# 0    9000                                    Election (1999)  7.294127     0
# 1    9000                             Song of Freedom (1936)  7.160518     1
# 2    9000                                Pulp Fiction (1994)  7.060320     2
# 3    9000                                Blade Runner (1982)  6.915018     3
# 4    9000  Star Wars: Episode VI - Return of the Jedi (1983)  6.711589     4
# 5    9000                          African Queen, The (1951)  6.710041     5
# 6    9000                           L.A. Confidential (1997)  6.585496     6
# 7    9000   Star Wars: Episode I - The Phantom Menace (1999)  6.523089     7
# 8    9000                                   Toy Story (1995)  6.495814     8
# 9    9000             Monty Python and the Holy Grail (1974)  6.413023     9
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Romace lover
# The top ten recommendations for the romance lover are the following:

# %%
romance_recommendations = optimal_model.recommend(new_data, users=[9001], k=10)
romance_recommendations.head(10)
# Out:
#    UserID                                         MovieTitle     score  rank
# 0    9001                                Forrest Gump (1994)  9.738085     0
# 1    9001                                       Fargo (1996)  9.501209     1
# 2    9001                                Galaxy Quest (1999)  9.076666     2
# 3    9001                               High Fidelity (2000)  9.015483     3
# 4    9001                                   Toy Story (1995)  8.618466     4
# 5    9001   Star Wars: Episode I - The Phantom Menace (1999)  8.581116     5
# 6    9001                        Being John Malkovich (1999)  8.498281     6
# 7    9001                               Groundhog Day (1993)  8.406502     7
# 8    9001  Star Wars: Episode VI - Return of the Jedi (1983)  8.205022     8
# 9    9001                           L.A. Confidential (1997)  8.195426     9
#
# [10 rows x 4 columns]
